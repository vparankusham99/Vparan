# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Muralidhar\wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
df.T
# Out:
#                      0        1        2        3       4        5        6    \
# Type                1.00     1.00     1.00     1.00    1.00     1.00     1.00
# Alcohol            14.23    13.20    13.16    14.37   13.24    14.20    14.39
# Malic               1.71     1.78     2.36     1.95    2.59     1.76     1.87
# Ash                 2.43     2.14     2.67     2.50    2.87     2.45     2.45
# Alcalinity         15.60    11.20    18.60    16.80   21.00    15.20    14.60
# Magnesium         127.00   100.00   101.00   113.00  118.00   112.00    96.00
# Phenols             2.80     2.65     2.80     3.85    2.80     3.27     2.50
# Flavanoids          3.06     2.76     3.24     3.49    2.69     3.39     2.52
# Nonflavanoids       0.28     0.26     0.30     0.24    0.39     0.34     0.30
# Proanthocyanins     2.29     1.28     2.81     2.18    1.82     1.97     1.98
# Color               5.64     4.38     5.68     7.80    4.32     6.75     5.25
# ...

# %%
df.corr()
# Out:
#                      Type   Alcohol     Malic       Ash  Alcalinity  \
# Type             1.000000 -0.328222  0.437776 -0.049643    0.517859
# Alcohol         -0.328222  1.000000  0.094397  0.211545   -0.310235
# Malic            0.437776  0.094397  1.000000  0.164045    0.288500
# Ash             -0.049643  0.211545  0.164045  1.000000    0.443367
# Alcalinity       0.517859 -0.310235  0.288500  0.443367    1.000000
# Magnesium       -0.209179  0.270798 -0.054575  0.286587   -0.083333
# Phenols         -0.719163  0.289101 -0.335167  0.128980   -0.321113
# Flavanoids      -0.847498  0.236815 -0.411007  0.115077   -0.351370
# Nonflavanoids    0.489109 -0.155929  0.292977  0.186230    0.361922
# Proanthocyanins -0.499130  0.136698 -0.220746  0.009652   -0.197327
# Color            0.265668  0.546364  0.248985  0.258887    0.018732
# Hue             -0.617369 -0.071747 -0.561296 -0.074667   -0.273955
# Dilution        -0.788230  0.072343 -0.368710  0.003911   -0.276769
# ...

# %%
sns.pairplot(df)

# %%
df1 = df.iloc[:,1:]
df1.head()
# Out:
#    Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df1_normal = sc.fit_transform(df1)

# %%
df1_normal
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 0.33275817,  1.74474449, -0.38935541, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 0.20923168,  0.22769377,  0.01273209, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.39508604,  1.58316512,  1.36520822, ..., -1.52437837,
#         -1.42894777, -0.59516041]])

# %%
cov_matrix = np.cov(df1_normal.T)
cov_matrix
# Out:
# array([[ 1.00564972,  0.09493026,  0.21273976, -0.31198788,  0.27232816,
#          0.29073446,  0.23815287, -0.15681042,  0.13747022,  0.549451  ,
#         -0.07215255,  0.07275191,  0.64735687],
#        [ 0.09493026,  1.00564972,  0.16497228,  0.29013035, -0.05488343,
#         -0.3370606 , -0.41332866,  0.29463237, -0.22199334,  0.25039204,
#         -0.56446685, -0.37079354, -0.19309537],
#        [ 0.21273976,  0.16497228,  1.00564972,  0.44587209,  0.28820583,
#          0.12970824,  0.11572743,  0.1872826 ,  0.00970647,  0.2603499 ,
#         -0.07508874,  0.00393333,  0.22488969],
#        [-0.31198788,  0.29013035,  0.44587209,  1.00564972, -0.0838039 ,
#         -0.32292752, -0.353355  ,  0.36396647, -0.19844168,  0.01883781,
#         -0.27550299, -0.27833221, -0.44308618],
#        [ 0.27232816, -0.05488343,  0.28820583, -0.0838039 ,  1.00564972,
#          0.21561254,  0.19688989, -0.25774204,  0.23777643,  0.20107967,
#          0.05571118,  0.06637684,  0.39557317],
# ...

# %%
values, vectors = np.linalg.eig(cov_matrix)

# %%
vectors
# Out:
# array([[-0.1443294 ,  0.48365155,  0.20738262, -0.0178563 , -0.26566365,
#          0.21353865,  0.05639636, -0.01496997,  0.39613926, -0.26628645,
#         -0.50861912, -0.22591696,  0.21160473],
#        [ 0.24518758,  0.22493093, -0.08901289,  0.53689028,  0.03521363,
#          0.53681385, -0.42052391, -0.02596375,  0.06582674,  0.12169604,
#          0.07528304,  0.07648554, -0.30907994],
#        [ 0.00205106,  0.31606881, -0.6262239 , -0.21417556, -0.14302547,
#          0.15447466,  0.14917061,  0.14121803, -0.17026002, -0.04962237,
#          0.30769445, -0.49869142, -0.02712539],
#        [ 0.23932041, -0.0105905 , -0.61208035,  0.06085941,  0.06610294,
#         -0.10082451,  0.28696914, -0.09168285,  0.42797018, -0.05574287,
#         -0.20044931,  0.47931378,  0.05279942],
#        [-0.14199204,  0.299634  , -0.13075693, -0.35179658,  0.72704851,
#          0.03814394, -0.3228833 , -0.05677422, -0.15636143,  0.06222011,
#         -0.27140257,  0.07128891,  0.06787022],
# ...

# %%
values
# Out:
# array([4.73243698, 2.51108093, 1.45424187, 0.92416587, 0.85804868,
#        0.64528221, 0.55414147, 0.10396199, 0.35046627, 0.16972374,
#        0.29051203, 0.22706428, 0.25232001])

# %%
explained_variances = []
for i in range(len(values)):
    explained_variances.append(values[i] / np.sum(values))
 
print(np.sum(explained_variances), '\n', explained_variances)
# Out:
# 1.0
#  [0.36198848099926356, 0.19207490257008933, 0.1112363053624999, 0.0706903018271403, 0.06563293679648596, 0.04935823319222561, 0.0423867932262332, 0.00795214889899452, 0.02680748948378865, 0.012982325756042076, 0.022221534047897094, 0.01736835689989916, 0.019300190939440763]

# %%
vectors.T[0]
# Out:
# array([-0.1443294 ,  0.24518758,  0.00205106,  0.23932041, -0.14199204,
#        -0.39466085, -0.4229343 ,  0.2985331 , -0.31342949,  0.0886167 ,
#        -0.29671456, -0.37616741, -0.28675223])

# %%
projected_1 = df_normal.dot(vectors.T[0])
projected_2 = df_normal.dot(vectors.T[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\MURALI~1\AppData\Local\Temp/ipykernel_1848/3414445316.py in <module>
# ----> 1 projected_1 = df_normal.dot(vectors.T[0])
#       2 projected_2 = df_normal.dot(vectors.T[1])
#
# ValueError: shapes (178,14) and (13,) not aligned: 14 (dim 1) != 13 (dim 0)

# %%
projected_1
# Out:
# array([ 3.5229339 ,  2.52885806,  2.78502898,  3.92258841,  1.40751111,
#         3.28812981,  2.75057754,  2.39286652,  2.79525633,  3.00559666,
#         3.67868855,  2.10963477,  2.43845636,  3.67349453,  4.44157575,
#         2.60892387,  2.47542846,  2.22623243,  3.74226929,  2.3944115 ,
#         3.33656895,  1.48140399,  2.82806867,  2.00771405,  2.11463604,
#         1.39753751,  2.13348803,  1.62970383,  2.50760753,  2.55948318,
#         2.77244452,  2.93513374,  1.99124842,  2.24570987,  1.78698628,
#         2.22763867,  1.76802847,  1.52317798,  1.87236494,  2.79711434,
#         2.84093569,  1.1055721 ,  3.30689482,  0.90479842,  2.39683569,
#         1.53781235,  2.99121644,  3.05931631,  2.31877146,  2.95947229,
#         3.4121813 ,  3.11637827,  3.70021113,  2.53754828,  2.44478924,
#         2.72281451,  2.98531677,  2.4881469 ,  3.35128665, -0.87492504,
#        -1.41466076, -1.71387916,  0.01229686,  1.83310122, -0.57453595,
# ...

# %%
projected_2
# Out:
# array([-1.45309844,  0.33001925, -1.03693595, -2.76821026, -0.86777309,
#        -2.13017513, -1.17916999, -1.61128232, -0.92317952, -0.79628417,
#        -1.31252342, -0.61298199, -0.67852331, -1.14012136, -2.11031917,
#        -1.66641801, -2.33089672, -1.63359016, -2.52840527, -1.06452946,
#        -0.79601279, -0.24008547,  0.08685755,  0.51561649,  0.31592057,
#        -0.93821529, -0.68710205,  0.09118403, -0.69274983, -0.1954729 ,
#        -1.24635279, -1.47827883, -0.05325201, -1.6346691 , -0.69748039,
#        -0.17928892, -0.65787231, -0.11222505,  0.76930576, -1.80880887,
#        -0.78616157, -0.16588492, -1.16395547, -0.32607243,  0.06690594,
#        -1.77507765, -1.19762255, -0.65382196, -1.25023668, -1.75860365,
#        -0.17691581, -0.75210873, -1.62309187, -1.87852793, -1.02071516,
#        -1.33524369, -1.44363759, -1.2154925 , -1.74060283,  3.07772383,
#         1.3899542 ,  0.83885608,  1.26269589,  1.91338608,  1.91115097,
# ...

# %%
res = pd.DataFrame(projected_1, columns=['PC1'])
res['PC2'] = projected_2

# %%
res
# Out:
#           PC1       PC2
# 0    3.522934 -1.453098
# 1    2.528858  0.330019
# 2    2.785029 -1.036936
# 3    3.922588 -2.768210
# 4    1.407511 -0.867773
# ..        ...       ...
# 173 -3.627996 -2.206617
# 174 -2.942729 -1.752263
# 175 -3.027272 -2.756040
# 176 -2.755222 -2.293784
# 177 -3.496336 -2.760608
#
# [178 rows x 2 columns]

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
pca_values = pca.fit_transform(df1_normal)

# %%
pca_values
# Out:
# array([[ 3.31675081, -1.44346263],
#        [ 2.20946492,  0.33339289],
#        [ 2.51674015, -1.0311513 ],
#        [ 3.75706561, -2.75637191],
#        [ 1.00890849, -0.86983082],
#        [ 3.05025392, -2.12240111],
#        [ 2.44908967, -1.17485013],
#        [ 2.05943687, -1.60896307],
#        [ 2.5108743 , -0.91807096],
#        [ 2.75362819, -0.78943767],
#        [ 3.47973668, -1.30233324],
#        [ 1.7547529 , -0.61197723],
#        [ 2.11346234, -0.67570634],
#        [ 3.45815682, -1.13062988],
#        [ 4.31278391, -2.09597558],
#        [ 2.3051882 , -1.66255173],
#        [ 2.17195527, -2.32730534],
#        [ 1.89897118, -1.63136888],
#        [ 3.54198508, -2.51834367],
#        [ 2.0845222 , -1.06113799],
#        [ 3.12440254, -0.78689711],
#        [ 1.08657007, -0.24174355],
#        [ 2.53522408,  0.09184062],
#        [ 1.64498834,  0.51627893],
#        [ 1.76157587,  0.31714893],
#        [ 0.9900791 , -0.94066734],
#        [ 1.77527763, -0.68617513],
# ...

# %%
pca.explained_variance_ratio_
# Out:
# array([0.36198848, 0.1920749 ])

# %%
pca = PCA(n_components = 6)
pca_values = pca.fit_transform(df1_normal)

# %%
pca_values
# Out:
# array([[ 3.31675081, -1.44346263, -0.16573904, -0.21563119,  0.69304284,
#         -0.22388013],
#        [ 2.20946492,  0.33339289, -2.02645737, -0.29135832, -0.25765463,
#         -0.92712024],
#        [ 2.51674015, -1.0311513 ,  0.98281867,  0.72490231, -0.25103312,
#          0.54927605],
#        ...,
#        [-2.67783946, -2.76089913, -0.94094188,  0.31203475,  1.271355  ,
#          0.27306792],
#        [-2.38701709, -2.29734668, -0.5506962 , -0.68828455,  0.81395522,
#          1.17878298],
#        [-3.20875816, -2.76891957,  1.01391366,  0.59690319, -0.89519259,
#          0.29609218]])

# %%
# The amount of variance that each PCA explains is 
var = pca.explained_variance_ratio_
var
# Out:
# array([0.36198848, 0.1920749 , 0.11123631, 0.0706903 , 0.06563294,
#        0.04935823])

# %%
# Cumulative variance 
var1 = np.cumsum(np.round(var,decimals = 4)*100)
var1
# Out:
# array([36.2 , 55.41, 66.53, 73.6 , 80.16, 85.1 ])

# %%
# Variance plot for PCA components obtained 
plt.plot(var1,color="red")
plt.grid()
plt.xlabel("No. of PC")
# Out:
# Text(0.5, 0, 'No. of PC')

# %%
# plot between PCA1 and PCA2 
x = pca_values[:,1]
y = pca_values[:,2]
#z = pca_values[:2:3]
plt.scatter(x,y)

# %%
finalDf = pd.concat([pd.DataFrame(pca_values[:,0:2],columns=['pc1','pc2']), df[['Type']]], axis = 1)

# %%
finalDf
# Out:
#           pc1       pc2  Type
# 0    3.316751 -1.443463     1
# 1    2.209465  0.333393     1
# 2    2.516740 -1.031151     1
# 3    3.757066 -2.756372     1
# 4    1.008908 -0.869831     1
# ..        ...       ...   ...
# 173 -3.370524 -2.216289     3
# 174 -2.601956 -1.757229     3
# 175 -2.677839 -2.760899     3
# 176 -2.387017 -2.297347     3
# 177 -3.208758 -2.768920     3
#
# [178 rows x 3 columns]

# %%
sns.scatterplot(data=finalDf,x='pc1',y='pc2',hue='Type')
# Out:
# <AxesSubplot:xlabel='pc1', ylabel='pc2'>

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=1, min_samples=5)
dbscan.fit(finalDf)
# Out:
# DBSCAN(eps=1)

# %%
len(dbscan.labels_)
# Out:
# 178

# %%
finalDf["Cluster"] = dbscan.labels_

# %%
finalDf
# Out:
#           pc1       pc2  Type  Cluster
# 0    3.316751 -1.443463     1        0
# 1    2.209465  0.333393     1        0
# 2    2.516740 -1.031151     1        0
# 3    3.757066 -2.756372     1        0
# 4    1.008908 -0.869831     1        0
# ..        ...       ...   ...      ...
# 173 -3.370524 -2.216289     3        2
# 174 -2.601956 -1.757229     3        2
# 175 -2.677839 -2.760899     3        2
# 176 -2.387017 -2.297347     3        2
# 177 -3.208758 -2.768920     3        2
#
# [178 rows x 4 columns]

# %%
idx = finalDf[finalDf["Cluster"]==-1].index
idx
# Out:
# Int64Index([73, 83, 95, 115, 121, 158], dtype='int64')

# %%
finalDf = finalDf.drop(idx, axis=0)

# %%
sns.scatterplot(data=finalDf,x='pc1',y='pc2',hue='Type')
# Out:
# <AxesSubplot:xlabel='pc1', ylabel='pc2'>

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2,random_state=0)
kmeans.fit(finalDf.iloc[:,[0,1]])
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
finalDf["Cluster group"] = kmeans.predict(finalDf.iloc[:,[0,1]])

# %%
finalDf
# Out:
#           pc1       pc2  Type  Cluster  Cluster group
# 0    3.316751 -1.443463     1        0              0
# 1    2.209465  0.333393     1        0              0
# 2    2.516740 -1.031151     1        0              0
# 3    3.757066 -2.756372     1        0              0
# 4    1.008908 -0.869831     1        0              0
# ..        ...       ...   ...      ...            ...
# 173 -3.370524 -2.216289     3        2              1
# 174 -2.601956 -1.757229     3        2              1
# 175 -2.677839 -2.760899     3        2              1
# 176 -2.387017 -2.297347     3        2              1
# 177 -3.208758 -2.768920     3        2              1
#
# [172 rows x 5 columns]

# %%
plt.scatter(finalDf[finalDf["Cluster group"]==0].pc1,finalDf[finalDf["Cluster group"]==0].pc2,color="red")
plt.scatter(finalDf[finalDf["Cluster group"]==1].pc1,finalDf[finalDf["Cluster group"]==1].pc2,color="green")
